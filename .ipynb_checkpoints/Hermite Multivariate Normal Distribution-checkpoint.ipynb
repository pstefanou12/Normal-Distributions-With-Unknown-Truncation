# %%
import sys 
sys.path.append('/Users/patroklos/Desktop/delphi_')

import torch as ch
from torch import Tensor
from torch.distributions.multivariate_normal import MultivariateNormal
import matplotlib.pyplot as plt
import IPython 

from delphi.distributions.unknown_truncation_multivariate_normal import TruncatedMultivariateNormal
from delphi import oracle
from delphi.utils import constants as consts
from delphi.utils.helpers import setup_store_with_metadata
from cox.utils import Parameters

# %%
args = Parameters({ 
    'samples': 10000, 
    'batch_size': 10, 
    'steps': 5000, 
    'tol': 1e-1, 
    'lr': 1e-1
})

# %% [markdown]
# Synthetic Data Experiment for 2 Dimensional Censored Gaussian Distributions

# %%
M = MultivariateNormal(ch.zeros(2), ch.eye(2))
samples = M.sample([args.samples])

plt.scatter(samples[:,0], samples[:,1])
plt.show()

# %% [markdown]
# Truncate the Dataset

# %%
phi = oracle.Right(Tensor([0.0]))
indices = phi(samples).nonzero(as_tuple=False)[:,0]
S = samples[indices]
alpha = S.size(0) / samples.size(0)
print("alpha: {}".format(alpha))

plt.scatter(S[:,0], S[:,1])
plt.show()
# Out:
# alpha: 1.0062

# %% [markdown]
# Run algorithm to Remove Bias from the Dataset

# %%
censored = CensoredMultivariateNormal(phi=phi, alpha=alpha, steps=args.steps)
censored.fit(S)
# Out:
# 100 Steps | Gradient Estimate: 0.5189316868782043
# 200 Steps | Gradient Estimate: 1.0486221313476562
# 300 Steps | Gradient Estimate: 2.4519577026367188
# 400 Steps | Gradient Estimate: 0.6279067993164062
# 500 Steps | Gradient Estimate: 0.9966892600059509
# 600 Steps | Gradient Estimate: 1.222201943397522
# 700 Steps | Gradient Estimate: 1.0118640661239624
# 800 Steps | Gradient Estimate: 0.4524320662021637
# 900 Steps | Gradient Estimate: 0.542841374874115
# 1000 Steps | Gradient Estimate: 2.255089044570923
# 1100 Steps | Gradient Estimate: 1.4346494674682617
# 1200 Steps | Gradient Estimate: 0.9093102812767029
# 1300 Steps | Gradient Estimate: 0.6461599469184875
# 1400 Steps | Gradient Estimate: 0.7300817370414734
# 1500 Steps | Gradient Estimate: 0.8520585894584656
# 1600 Steps | Gradient Estimate: 0.4890143871307373
# 1700 Steps | Gradient Estimate: 0.6403016448020935
# 1800 Steps | Gradient Estimate: 0.5317962765693665
# 1900 Steps | Gradient Estimate: 1.1766170263290405
# 2000 Steps | Gradient Estimate: 1.4565963745117188
# 2100 Steps | Gradient Estimate: 1.2324415445327759
# 2200 Steps | Gradient Estimate: 0.4229024052619934
# 2300 Steps | Gradient Estimate: 1.0511037111282349
# 2400 Steps | Gradient Estimate: 0.5902736783027649
# 2500 Steps | Gradient Estimate: 0.6868177056312561
# 2600 Steps | Gradient Estimate: 0.6222271919250488
# 2700 Steps | Gradient Estimate: 0.6321396231651306
# 2800 Steps | Gradient Estimate: 0.7732924222946167
# 2900 Steps | Gradient Estimate: 0.3945074677467346
# 3000 Steps | Gradient Estimate: 0.2615809738636017
# 3100 Steps | Gradient Estimate: 1.5140666961669922
# 3200 Steps | Gradient Estimate: 0.5907014012336731
# 3300 Steps | Gradient Estimate: 1.9358340501785278
# 3400 Steps | Gradient Estimate: 0.6585557460784912
# 3500 Steps | Gradient Estimate: 0.5062815546989441
# 3600 Steps | Gradient Estimate: 1.1794798374176025
# 3700 Steps | Gradient Estimate: 0.7007768154144287
# 3800 Steps | Gradient Estimate: 1.004093050956726
# 3900 Steps | Gradient Estimate: 3.561694622039795
# 4000 Steps | Gradient Estimate: 0.8653156161308289

# %%
S

# %%
00
